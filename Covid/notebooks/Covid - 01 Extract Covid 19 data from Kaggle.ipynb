# %%
#Extracting data from Kaggle site
import requests
from requests import session
import os
import csv

# %%
#Login Url
login_url = 'https://www.kaggle.com/account/login'
#url for train file (get the link from kaggle website)
url_agegroup = 'https://www.kaggle.com/sudalairajkumar/covid19-in-india/download/AgeGroupDetails.csv'
url_covid19 = 'https://www.kaggle.com/sudalairajkumar/covid19-in-india/download/covid_19_india.csv'
url_hospital_beds = 'https://www.kaggle.com/sudalairajkumar/covid19-in-india/download/HospitalBedsIndia.csv'
url_icmr_testing = 'https://www.kaggle.com/sudalairajkumar/covid19-in-india/download/ICMRTestingLabs.csv'
url_individual_details = 'https://www.kaggle.com/sudalairajkumar/covid19-in-india/download/IndividualDetails.csv'
url_population_details = 'https://www.kaggle.com/sudalairajkumar/covid19-in-india/download/population_india_census2011.csv'
url_statewise_details = 'https://www.kaggle.com/sudalairajkumar/covid19-in-india/download/StatewiseTestingDetails.csv'

# %%
#file paths
raw_data_path = 'C:/Users/shedgep/DataScience/Covid/raw'
agegroup_data_path = os.path.join(raw_data_path,'AgeGroupDetails.csv')

# %%
#Credentials of machine
KAGGLE_USERNAME = 'prafullpshedge'
KAGGLE_PASSWORD = 'Parth@359'

# %%
#payload for post
payload = {
    'action' : 'login',
    'username' : KAGGLE_USERNAME,
    'password' : KAGGLE_PASSWORD
}
login_data =  {'formPosted':'1', 'login_email':'prafullshedge@gmail.com', 'password':'Parth@359'}

# %%
x = requests.post(login_url, data = login_data)
print(x.text)

# %%
#payload for post
payload = {
    'action' : 'login',
    'username' : 'prafullpshedge',
    'password' : 'Parth@359'
}

#setup session
with session() as c:
    c.post('https://www.kaggle.com/account/login', data=payload)
    response = c.get(url_agegroup)
    print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Kaggle: Your Home for Data Science</title>
#     <meta charset="utf-8" />
#     <meta name="robots" content="index, follow" />
#     <meta name="description" content="Kaggle is the world&#x2019;s largest data science community with powerful tools and resources to help you achieve your data science goals." />
#     <meta name="turbolinks-cache-control" content="no-cache" />
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#     <meta name="theme-color" content="#008ABC" />
#     <script nonce="myYDUg036rITmU8CqV&#x2B;GLw==" type="text/javascript">
#         if ('serviceWorker' in navigator) {
#             navigator.serviceWorker.getRegistrations()
#                 .then(function(registrations) {
#                     for (let registration of registrations) {
#                         registration.unregister();
#                     }
#                 })
# ...

# %%
def extract_data(url,file_path):
    '''
    extract data from kaggle
    '''
    #setup session
    with session() as c:
        r = c.post('https://www.kaggle.com/account/login', data=payload)
        print('Login Response: ',r.text)
        #open file to write
        with open(file_path,'w') as handle:
            response = c.get(url,stream=True)
            print('Url Stream: ', response.text)
            for block in response.iter_content(1024):
                handle.write(block)

# %%
#extract data
extract_data(url_agegroup,agegroup_data_path)
# Out:
# Login Response:
# Url Stream:  <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Kaggle: Your Home for Data Science</title>
#     <meta charset="utf-8" />
#     <meta name="robots" content="index, follow" />
#     <meta name="description" content="Kaggle is the world&#x2019;s largest data science community with powerful tools and resources to help you achieve your data science goals." />
#     <meta name="turbolinks-cache-control" content="no-cache" />
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#     <meta name="theme-color" content="#008ABC" />
#     <script nonce="2uUn5lkRZjYte1BHFXiSkg==" type="text/javascript">
#         if ('serviceWorker' in navigator) {
#             navigator.serviceWorker.getRegistrations()
#                 .then(function(registrations) {
#                     for (let registration of registrations) {
#                         registration.unregister();
# ...

# %%
payload = {
    '__RequestVerificationToken': '',
    'username': 'prafullpshedge',
    'password': 'Parth@359',
    'rememberme': 'false'
}

# %%
with requests.Session() as c:
    response = c.get(login_url).text
    AFToken = response[response.index('antiForgeryToken')+19:response.index('isAnonymous: ')-12]
    print("AntiForgeryToken={}".format(AFToken))
    payload['__RequestVerificationToken']=AFToken
    c.post(login_url + "?isModal=true&returnUrl=/", data=payload)
    download = c.get(url_agegroup)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
    for row in my_list:
        print(row)


#df = pd.DataFrame(my_list)
#header = df.iloc[0]
#df = df[1:]
#diab = df.set_axis(header, axis='columns', inplace=False)
# Out:
# AntiForgeryToken=CfDJ8LdUzqlsSWBPr4Ce3rb9VL9bDBGwHbh1qVQPt-y7ctkbA06d-JDEBkyrr3d8w3okaJkkK-9-BXXM1e03bbY5dkc-pAggp4waoPeU-cndWH1zJnpxvg-xDLlpDEKKFGz-CVyqVyy9M_gmgcqz1cQKTwo
# ['<!DOCTYPE html>']
# ['<html lang="en">']
# ['<head>']
# ['    <title>Kaggle: Your Home for Data Science</title>']
# ['    <meta charset="utf-8" />']
# ['    <meta name="robots" content="index', ' follow" />']
# ['    <meta name="description" content="Kaggle is the world&#x2019;s largest data science community with powerful tools and resources to help you achieve your data science goals." />']
# ['    <meta name="turbolinks-cache-control" content="no-cache" />']
# ['        <meta name="viewport" content="width=device-width', ' initial-scale=1.0', ' maximum-scale=5.0', ' minimum-scale=1.0">']
# ['    <meta name="theme-color" content="#008ABC" />']
# ['    <script nonce="sy0/7c3hG59RCpqYhqxdvw==" type="text/javascript">']
# ["        if ('serviceWorker' in navigator) {"]
# ...
